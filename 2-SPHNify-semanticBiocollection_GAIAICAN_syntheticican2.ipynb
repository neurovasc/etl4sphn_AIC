# %%
# import libaries 
# %pip install pandas rdflib scipy
import pandas as pd
from rdflib import Dataset
from string import Template
from datetime import datetime, timedelta
from IPython.display import display

# verbosity
verbose = True

# data
synicadf = pd.read_csv("data/syntheticican2/ucanNeurovascSimulatedData_14042025.csv", sep=",")
if verbose == True:
    display(synicadf.head())

# ontology terms
## for coding tracking use, because there are too many terms to memorize
ontologyTermsExplained = {
    'hpo:0007029': 'Cerebral berry aneurysm', 
    'hpo:0100546': 'Carotid artery stenosis', 
    'hpo:0004942': 'Aortic aneurysm',
    'hpo:0000822': 'Arterial hypertension', 
    'hpo:0008071': 'Maternal hypertension', 
    'hpo:0032320' : 'Affected family member', 
    'pato:0002118' : 'Multiple quantity (here, aneursysms)', 
    'hpo:0100651': 'Diabetes mellitus type 1',
    'hpo:0005978': 'Diabetes mellitus type 2',
    'hpo:0009800': 'Maternal diabetes mellitus', 
    'hpo:0003119': 'Dyslipidemia'}
## for the knowledge graph
ontologyTerms = {'presenceOfAneurysm' : 'hpo:0007029', 
                 'carotidArteryStenosis' : 'hpo:0100546', 
                 'aorticAneurysm' : 'hpo:0004942', 
                 'arterialHypertension' : 'hpo:0000822', 
                 'maternalHypertension' : 'hpo:0008071', 
                 'familialCase' : 'hpo:0032320', 
                 'multipleAneurysms' : 'pato:0002118', 
                 'diabetesMellitusType1' : 'hpo:0100651',
                 'diabetesMellitusType2' : 'hpo:0005978',
                 'maternalDiabetes' : 'hpo:0009800', 
                 'dyslipidemia' : 'hpo:0003119'}
# Out:
# Requirement already satisfied: pandas in ./myenv/lib/python3.12/site-packages (2.2.3)
# Requirement already satisfied: rdflib in ./myenv/lib/python3.12/site-packages (7.1.4)
# Requirement already satisfied: scipy in ./myenv/lib/python3.12/site-packages (1.15.3)
# Requirement already satisfied: numpy>=1.26.0 in ./myenv/lib/python3.12/site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./myenv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./myenv/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./myenv/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in ./myenv/lib/python3.12/site-packages (from rdflib) (3.2.3)
# Requirement already satisfied: six>=1.5 in ./myenv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
#   biosampleId  sampleType-arterialBlood  sampleType-veinousBlood    patientId  \
# 0     HG00096                      True                    False  pid_HG00096
# 1     HG00097                      True                    False  pid_HG00097
# 2     HG00099                      True                    False  pid_HG00099
# 3     HG00100                      True                    False  pid_HG00100
# 4     HG00101                      True                    False  pid_HG00101
#
#   inclusionNb               referralCenter consent sex lifeStatus  \
# 0    AIC_09_0                        Dijon     Yes   M      alive
# 1    AIC_01_1                       Angers     Yes   F      alive
# 2    AIC_08_2  Paris – Hopital Sainte Anne     Yes   F      alive
# 3    AIC_06_3                        Tours     Yes   M      alive
# 4    AIC_05_4                       Nantes     Yes   F      alive
#
#    firstDiagnosisAge  ...  aic-5-locationCode aic-5-locationDetail  \
# 0                 40  ...                 NaN                  NaN
# 1                 70  ...                 NaN                  NaN
# 2                 63  ...                 NaN                  NaN
# 3                 49  ...                 NaN                  NaN
# 4                 45  ...                 NaN                  NaN
#
#    aic-5-locationVessel  aic-5-locationSide aic-5-size  aic-5-rupture  \
# 0                   NaN                 NaN        NaN            NaN
# 1                   NaN                 NaN        NaN            NaN
# 2                   NaN                 NaN        NaN            NaN
# 3                   NaN                 NaN        NaN            NaN
# 4                   NaN                 NaN        NaN            NaN
#
#    aic-5-patientAgeAtRupture  aic-5-treatment  aic-5-patientAgeAtTreatment  \
# 0                        NaN              NaN                          NaN
# 1                        NaN              NaN                          NaN
# 2                        NaN              NaN                          NaN
# 3                        NaN              NaN                          NaN
# 4                        NaN              NaN                          NaN
#
#    aic-5-treatmentType
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
# [5 rows x 93 columns]

# %%
synicadf.rename(columns={"patientId": "pid", 
                         "bodyMassIndex": "bmi", 
                         "medicalHistory-cardioVascular-carotidArteryStenosis" : "carotidArteryStenosis",
                         "medicalHistory-cardioVascular-aorticAneurysm" : "aorticAneurysm", 
                         "medicalHistory-arterialHypertension" : "arterialHypertension", 
                         "medicalHistory-arterialHypertension-gestational" : "maternalHypertension", 
                         "medicalHistory-diabetes_gestational" : "maternalDiabetes",
                         "medicalHistory-diabetes_type1" : "diabetesMellitusType1",
                         "medicalHistory-diabetes_type2" : "diabetesMellitusType2", 
                         "medicalHistory-dyslipidemia" : "dyslipidemia", 
                         "medicalHistory-treatments-statines" : "treatmentStatines",
                         "medicalHistory-treatments-antiplatelet" : "treatmentAntiplatelet", 
                         "medicalHistory-treatments-anticoagulant" : "treatmentAnticoagulant"}, 
                        inplace=True)
synicadf['age'] = synicadf.loc[:,'firstDiagnosisAge'] # for simulated data, age and ageat diagnosis of aneurysms are the same
synicadf['pid'] = synicadf['pid'].replace('HG', 'SIM', regex=True) # SIM pour Simulated
synicadf['biosampleId'] = synicadf['biosampleId'].replace('HG', 'SIM', regex=True) # SIM pour Simulated
synicadf['pid'] = synicadf['pid'].replace('NA', 'SIM', regex=True) # SIM pour Simulated
synicadf['biosampleId'] = synicadf['biosampleId'].replace('NA', 'SIM', regex=True) # SIM pour Simulated
synicadf['presenceOfAneurysm'] = True
if verbose == True:
    display(synicadf.head())
# Out:
#   biosampleId  sampleType-arterialBlood  sampleType-veinousBlood  \
# 0    SIM00096                      True                    False
# 1    SIM00097                      True                    False
# 2    SIM00099                      True                    False
# 3    SIM00100                      True                    False
# 4    SIM00101                      True                    False
#
#             pid inclusionNb               referralCenter consent sex  \
# 0  pid_SIM00096    AIC_09_0                        Dijon     Yes   M
# 1  pid_SIM00097    AIC_01_1                       Angers     Yes   F
# 2  pid_SIM00099    AIC_08_2  Paris – Hopital Sainte Anne     Yes   F
# 3  pid_SIM00100    AIC_06_3                        Tours     Yes   M
# 4  pid_SIM00101    AIC_05_4                       Nantes     Yes   F
#
#   lifeStatus  firstDiagnosisAge  ...  aic-5-locationVessel aic-5-locationSide  \
# 0      alive                 40  ...                   NaN                NaN
# 1      alive                 70  ...                   NaN                NaN
# 2      alive                 63  ...                   NaN                NaN
# 3      alive                 49  ...                   NaN                NaN
# 4      alive                 45  ...                   NaN                NaN
#
#    aic-5-size  aic-5-rupture aic-5-patientAgeAtRupture  aic-5-treatment  \
# 0         NaN            NaN                       NaN              NaN
# 1         NaN            NaN                       NaN              NaN
# 2         NaN            NaN                       NaN              NaN
# 3         NaN            NaN                       NaN              NaN
# 4         NaN            NaN                       NaN              NaN
#
#    aic-5-patientAgeAtTreatment  aic-5-treatmentType  age  presenceOfAneurysm
# 0                          NaN                  NaN   40                True
# 1                          NaN                  NaN   70                True
# 2                          NaN                  NaN   63                True
# 3                          NaN                  NaN   49                True
# 4                          NaN                  NaN   45                True
#
# [5 rows x 95 columns]

# %%
# jinja style templates 
# prefix and templates 
prefix = """@prefix sphn: <https://biomedit.ch/rdf/sphn-schema/sphn#> .
@prefix ican: <http://ican.ressource.org/> .
@prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
@prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
@prefix efo: <http://www.ebi.ac.uk/efo/EFO_> .
@prefix obo: <http://purl.obolibrary.org/obo/> .
@prefix obi: <http://purl.obolibrary.org/obo/OBI_> .
@prefix iao: <http://purl.obolibrary.org/obo/IAO_> .
@prefix ncit: <http://purl.obolibrary.org/obo/NCIT_> .
@prefix hpo: <http://purl.obolibrary.org/obo/HPO_> .
@prefix ucum: <https://ucum.org/ucum#> .
@prefix pato: <http://purl.obolibrary.org/obo/PATO_> . 
@prefix duo: <http://purl.obolibrary.org/obo/DUO_> .
@prefix chebi: <http://purl.obolibrary.org/obo/CHEBI_> . 
"""

# ican individual identifier
sphn_person_template = Template(
    """
    $person_iri a ncit:C25190 .
    $person_iri rdfs:label "person profile simulatd with probabilities from the ICAN Biocollection"^^xsd:string . 
    $person_iri rdf:type efo:0022043 . 
    $person_iri rdf:type ncit:C16960 .
    $person_iri rdf:type sphn:SubjectPseudoIdentifier .
    $person_iri sphn:hasIdentifier "$person_id"^^xsd:string .
    $person_iri sphn:hasDataProvider $dataProvider_iri .
    """
)
# age of individual at study time
sphn_age_template = Template(
    """
    $age_iri a sphn:Age .
    $age_iri a obi:0001167 .
    $age_iri rdfs:label "age of the individual at study time"^^xsd:string .
    $age_iri sphn:hasDeterminationDateTime "$age_determination_date"^^xsd:dateTime .
    $age_iri sphn:hasQuantity $ageQuantity_iri . 
    $ageQuantity_iri a sphn:Quantity ;
            sphn:hasValue "$age_value"^^xsd:decimal ;
            sphn:hasUnit ucum:$ageUnit .
    $age_iri sphn:hasSubjectPseudoIdentifier $person_iri .
    """
)
# administrative sex (no info about gender roles tbh)
sphn_sex_template = Template(
    """
    $sex_iri a sphn:AdministrativeSex, ncit:C17357 ;
            sphn:hasCode $sex_value .
    $sex_iri sphn:hasSubjectPseudoIdentifier $person_iri .
    """
)
# body mass index
sphn_bmi_template = Template(
    """
    $bmi_iri a sphn:BodyMassIndex.
    $bmi_iri a  ncit:C16358 .
    $bmi_iri rdfs:label "Body Mass Index of the individual at study time"^^xsd:string .
    $bmi_iri sphn:hasDeterminationDateTime "$bmi_determination_date"^^xsd:dateTime .
    $bmi_iri sphn:hasQuantity $bmiQuantity_iri .
    $bmiQuantity_iri a sphn:Quantity ;
            sphn:hasValue "$bmi_value"^^xsd:decimal ;
            sphn:hasUnit ucum:$bmiUnit .
    $bmi_iri sphn:hasSubjectPseudoIdentifier $person_iri .
    """
)
# diagnosis
# https://www.biomedit.ch/rdf/sphn-schema/sphn#Diagnosis
# Aneurysm is special because there is an age at diagnosis, cardinality, familial status, other info etc
sphn_diagnosisAneurysmAgeDetail_code_template = Template(
    """
    $diagnosis_iri sphn:hasSubjectAge $ageAtDiagnosis_iri .
    $ageAtDiagnosis_iri a sphn:Age .
    $ageAtDiagnosis_iri a obi:0001167 .
    $ageAtDiagnosis_iri rdfs:label "age of the individual at first diagnosis of intracranial aneurysm"^^xsd:string .
    $ageAtDiagnosis_iri sphn:hasQuantity $ageAtDiagnosisQuantity_iri . 
    $ageAtDiagnosisQuantity_iri a sphn:Quantity ;
            sphn:hasValue "$ageAtDiagnosis_value"^^xsd:decimal ;
            sphn:hasUnit ucum:$ageUnit .
    $ageAtDiagnosis_iri sphn:hasSubjectPseudoIdentifier $person_iri .
    $diagnosis_iri sphn:hasSubjectPseudoIdentifier $person_iri .
    """
)
sphn_diagnosisAneurysmFormDetail_code_template = Template(
    """
    $diagnosis_iri sphn:hasCode $diagnosisFormDetail_code .
    $diagnosis_iri rdfs:label "$diagnosisFormDetail_label"^^xsd:string .
    $diagnosis_iri sphn:hasSubjectPseudoIdentifier $person_iri .
    """
)
# All diagnosis, boolean, unique code being enough to identify the diagnosis
sphn_diagnosis_code_template = Template(
    """
    $diagnosis_iri a sphn:Diagnosis .
    $diagnosis_iri rdfs:label "$diagnosis_label"^^xsd:string .
    $diagnosis_iri sphn:hasCode $diagnosis_code .
    $diagnosis_iri sphn:hasSubjectPseudoIdentifier $person_iri .
    """
)
# Data provider
sphn_data_provider_template = Template(
    """
    $dataProvider_iri a sphn:DataProvider ;
        sphn:hasInstitutionCode "l institut du thorax UMR1087 Inserm"^^xsd:string ;
        sphn:hasCategory "research institute"^^xsd:string .
    """
)
# Biobanksample
sphn_biobanksample_template = Template(
    """
    $biobanksample_iri a sphn:BiobankSample .
    $biobanksample_iri rdfs:label "Biobank sample of the simulated individual from the ICAN Biocollection"^^xsd:string .
    $biobanksample_iri sphn:hasIdentifier "$biobanksample_id"^^xsd:string .
    $biobanksample_iri sphn:hasSubjectPseudoIdentifier $person_iri .
    """
)
# Consent 
sphn_consent_template = Template(
    """
    $consent_iri a sphn:Consent .
    $consent_iri sphn:hasStatusCode "active"^^xsd:string .
    $consent_iri sphn:hasTypeCode $consent_code .
    $consent_iri sphn:hasSubjectPseudoIdentifier $person_iri .
    """
)
# Imaging Procedure (to include the ICAN/UCAN inclusion number, which then can be used to retrieve imaging metadata with Shanoir)
sphn_imagingProcedure_template = Template(
    """
    $imagingProcedure_iri a sphn:ImagingProcedure .
    $imagingProcedure_iri rdfs:label "Imaging procedure for the simulated individual from the ICAN Biocollection, the identifier being the [I|U]CAN inclusion number"^^xsd:string .
    $imagingProcedure_iri sphn:hasIdentifier "$imagingProcedure_id"^^xsd:string .
    $imagingProcedure_iri sphn:hasSubjectPseudoIdentifier $person_iri .
    $imagingProcedure_iri sphn:hasBodySite $imagingProcedureBodySite_iri .
    $imagingProcedureBodySite_iri a sphn:BodySite .
    $imagingProcedureBodySite_iri rdfs:label "Intracranial vasculature"^^xsd:string .
    $imagingProcedureBodySite_iri sphn:hasCode $bodySite .
    $imagingProcedure_iri sphn:hasSubjectPseudoIdentifier $person_iri .
    """
)
# Drug Prescription (statines, antiplatelet, anticoagulants)
# NB, contrary to real sphn ontology, I don't have Drug related to Substance which in turn has code. 
# Drug :hasCode directly (for simplicity, tbh, this is simulated data). 
sphn_drugPrescription_template = Template(
    """
    $drugPrescription_iri a sphn:DrugPrescription .
    $drugPrescription_iri sphn:hasDrug $prescribedDrug_iri .
    $prescribedDrug_iri a sphn:Drug .
    $prescribedDrug_iri sphn:hasCode $drug_code .
    $drugPrescription_iri sphn:hasRecordDateTime "$drugPrescription_record_date"^^xsd:dateTime .
    $drugPrescription_iri sphn:hasSubjectPseudoIdentifier $person_iri .
    """
)

# %%
# semantic ICAN individual
class SemanticPerson:
    def __init__(self, row):
        self.row = row

    # iri contructors
    def get_pid(self):
        return {'iri': "<http://ican.ressource.org/individual/" + str(self.row['pid']) + ">" , 
                'value' : self.row['pid']}
    
    def get_biobanksample(self):
        return {'iri': "<http://ican.ressource.org/individual/"+str(self.row['pid'])+"/biobanksample/" + str(self.row['biosampleId']) + ">" , 
                'value' : self.row['biosampleId']}
    
    def get_consent(self):
        return {'iri': "<http://ican.ressource.org/individual/" + str(self.row['pid']) + '/consent/' + str(self.row['consent']) + ">", 
                'value' :  self.row['consent'], 
                'code' : "<http://purl.obolibrary.org/obo/DUO_0000037>"}
    
    def get_imagingProcedure(self):
        return {'iri': "<http://ican.ressource.org/individual/" + str(self.row['pid']) + '/imagingProcedure/' + str(self.row['inclusionNb']) + ">", 
                'id' :  self.row['inclusionNb'], 
                'bodySite_iri' : "<http://ican.ressource.org/individual/" + str(self.row['pid']) + '/imagingProcedure/' + str(self.row['inclusionNb']) + "/bodySite/brain>",
                'bodySite' : "<http://purl.obolibrary.org/obo/UBERON_0000955>" }
    
    def get_prescribedDrug(self, drug_column):
        drug_code = {'treatmentStatines' : 'chebi:87631', 'treatmentAntiplatelet' : 'ncit:C1327', 'treatmentAnticoagulant' : 'chebi:50249'}
        return {'prescription_iri': "<http://ican.ressource.org/individual/" + str(self.row['pid']) + '/drugPrescription/' + drug_column + ">",
                'drug_iri' : "<http://ican.ressource.org/drug/" + drug_column + ">",
                'drug_code' : drug_code[drug_column],
                'recordTime' : "2018-01-01T00:00:00"}
    
    def get_age(self):
        return {'iri': "<http://ican.ressource.org/individual/" + str(self.row['pid']) + '/age/' + str(self.row['age']) + ">", 
                'value' :  self.row['age'] }
    
    def get_ageAtDiagnosis(self, diagnosis_column):
        if diagnosis_column == 'presenceOfAneurysm':
            ageAtDiagnosis = self.row['firstDiagnosisAge']
            return {'iri': "<http://ican.ressource.org/individual/" + str(self.row['pid']) + '/ageAtDiagnosis/' + str(ageAtDiagnosis) + ">", 
                    'value' :  ageAtDiagnosis }
        else:
            exit("Age at diagnosis is only available for presence of aneurysm, other diagnoses do not have an age at diagnosis in the simulated data.")

    def get_bmi(self):
        return {'iri': "<http://ican.ressource.org/individual/" + str(self.row['pid']) + '/bmi/' + str(self.row['bmi']).replace(".", "_") + ">", 
                'value' :  self.row['bmi'] }

    def get_sex(self):
        sexCode = {'M' : 'ncit:C20197', 'F' : 'ncit:C16576', 'U' : 'ncit:C17998'}
        return {'iri': "<http://ican.ressource.org/individual/" + str(self.row['pid']) + '/sex/' + str(self.row['sex']) + ">", 
                'value' :  sexCode[self.row['sex']] }

    def get_dataProvider(self):
        return {'iri': "<http://ican.ressource.org/organisation/dataProvider#" + 'ITXUMR1087' + '>' , 
                'value' : 'ITXUMR1087'}
    
    def get_diagnosis(self, diagnosis_column):
        diagnosis_status = self.row[diagnosis_column]
        diagnosis_label = ontologyTermsExplained[ontologyTerms[diagnosis_column]]
        diagnosis_code = ontologyTerms[diagnosis_column]
        diagnosis_iri = "<http://ican.ressource.org/individual/" + str(self.row['pid']) + '/diagnosis/' + diagnosis_label.replace(' ', '_') + ">"
        return {'status': diagnosis_status, 
                'iri': diagnosis_iri, 
                'label' : diagnosis_label, 
                'code' : diagnosis_code}
    
    def get_quantity(self, quantityName, unitName):
        ucum = {
            'ageAtDiagnosis' : 'a_j',
            'ageAtStudyTime' : 'a_j', 
            'bmi' : 'm-2.g',}
        return {'iri': "<http://ican.ressource.org/individual/" + str(self.row['pid']) + '/quantity/' + str(quantityName).replace(".", "_") + ">", 
                'unit' : ucum[unitName]}
    
    # diagnosis rdf generation
    def add_diagnosis_rdf(semanticPerson, rdf, diagnosis_manualLabel):
        diagnosis_status, diagnosis_iri, diagnosis_label, diagnosis_code = semanticPerson.get_diagnosis(diagnosis_manualLabel).values()
        if diagnosis_status == True:
            rdf += sphn_diagnosis_code_template.substitute(
                person_iri=semanticPerson.get_pid()['iri'],
                diagnosis_iri=diagnosis_iri,
                diagnosis_label=diagnosis_label,
                diagnosis_code=diagnosis_code
            )
            if diagnosis_manualLabel == 'presenceOfAneurysm':
                # age and additional descriptors
                ageAtDiagnosis_iri, ageAtDiagnosis_value = semanticPerson.get_ageAtDiagnosis('presenceOfAneurysm').values()
                ageAtDiagnosisQuantity_iri, ageAtDiagnosisUnit = semanticPerson.get_quantity('ageAtDiagnosis','ageAtDiagnosis').values()
                #
                rdf += sphn_diagnosisAneurysmAgeDetail_code_template.substitute(
                    person_iri=semanticPerson.get_pid()['iri'],
                    diagnosis_iri=diagnosis_iri,
                    ageAtDiagnosis_iri=ageAtDiagnosis_iri,
                    ageAtDiagnosis_value=ageAtDiagnosis_value,
                    ageAtDiagnosisQuantity_iri=ageAtDiagnosisQuantity_iri,
                    ageUnit=ageAtDiagnosisUnit 
                )
                modifiers = ['familialCase', 'multipleAneurysms']#, 'sporadicCase', 
                for mod in modifiers: 
                    if semanticPerson.row[mod] == True :
                        rdf += sphn_diagnosisAneurysmFormDetail_code_template.substitute(
                            person_iri=semanticPerson.get_pid()['iri'],
                            diagnosis_iri=diagnosis_iri,
                            diagnosisFormDetail_code=ontologyTerms[mod],
                            diagnosisFormDetail_label=ontologyTermsExplained[ontologyTerms[mod]]
                        )
        return rdf
    # treatment
    def add_drugPrescription_rdf(semanticPerson, rdf, drug_column):
        if semanticPerson.row[drug_column] == True:
            drugPrescription_iri, drug_iri, drug_code, recordTime = semanticPerson.get_prescribedDrug(drug_column).values()
            rdf += sphn_drugPrescription_template.substitute(
                person_iri=semanticPerson.get_pid()['iri'],
                drugPrescription_iri=drugPrescription_iri,
                prescribedDrug_iri=drug_iri,
                drug_code=drug_code,
                drugPrescription_record_date=recordTime
            )
        return rdf
    
#

def generate_semanticBiollection_rdf(row, kg):
    semanticPerson = SemanticPerson(row)

    # patient id
    person_iri, person_id = semanticPerson.get_pid().values()
    # age
    age_iri, age_value = semanticPerson.get_age().values()
    ageQuantity_iri, ageUnit = semanticPerson.get_quantity('ageAtStudyTime','ageAtStudyTime').values()
    age_determination_date = "2018-01-01T00:00:00"
    # administrative gender
    sex_iri, sex_value = semanticPerson.get_sex().values()
    # data provider 
    dataProvider_iri, dataProvider_value = semanticPerson.get_dataProvider().values()
    # biobanksample
    biobanksample_iri, biobanksample_id = semanticPerson.get_biobanksample().values()
    # consent
    consent_iri, consent_value, consent_code = semanticPerson.get_consent().values()
    # imaging procedure 
    imagingProcedure_iri, imagingProcedure_id, imagingProcedureBodySite_iri, bodySite = semanticPerson.get_imagingProcedure().values()
    # person, admistrative sex, age
    rdf = \
        sphn_person_template.substitute(
                            person_iri=person_iri, 
                            person_id=person_id, 
                            dataProvider_iri=dataProvider_iri) + \
        sphn_age_template.substitute(
                            person_iri=person_iri,
                            age_iri=age_iri,
                            age_value=f"{age_value:.1f}",
                            age_determination_date=age_determination_date, 
                            ageQuantity_iri=ageQuantity_iri, 
                            ageUnit=ageUnit) + \
        sphn_sex_template.substitute(
                            person_iri=person_iri,
                            sex_iri=sex_iri, 
                            sex_value=sex_value ) + \
        sphn_data_provider_template.substitute(
                            dataProvider_iri=dataProvider_iri) + \
        sphn_biobanksample_template.substitute(
                            biobanksample_iri=biobanksample_iri, 
                            biobanksample_id=biobanksample_id, 
                            person_iri=person_iri) + \
        sphn_consent_template.substitute(
                            consent_iri=consent_iri, 
                            consent_code=consent_code,
                            person_iri=person_iri) + \
        sphn_imagingProcedure_template.substitute(
                            imagingProcedure_iri=imagingProcedure_iri, 
                            imagingProcedure_id=imagingProcedure_id, 
                            imagingProcedureBodySite_iri=imagingProcedureBodySite_iri,
                            bodySite=bodySite,
                            person_iri=person_iri)
    # bmi if available
    # bmi
    bmi_iri, bmi_value = semanticPerson.get_bmi().values()
    bmiQuantity_iri, bmiUnit = semanticPerson.get_quantity('bmi','bmi').values()
    bmi_determination_date = "2018-01-01T00:00:00"
    if not pd.isna(bmi_value):
        rdf += \
            sphn_bmi_template.substitute(
                                person_iri=person_iri,
                                bmi_iri=bmi_iri, 
                                bmi_value=bmi_value,
                                bmiUnit=bmiUnit,
                                bmiQuantity_iri=bmiQuantity_iri,
                                bmi_determination_date=bmi_determination_date)
    # diagnosis
    ### status -> true or false, will be used to generate or not the sphn diagnosis
    ## presence of intracranial aneurysm
    rdf += semanticPerson.add_diagnosis_rdf(rdf, 'presenceOfAneurysm')
    ## carotid artery stenosis
    rdf += semanticPerson.add_diagnosis_rdf(rdf, 'carotidArteryStenosis')
    ## aortic aneurysm
    rdf += semanticPerson.add_diagnosis_rdf(rdf, 'aorticAneurysm')
    ## arterialHypertension
    rdf += semanticPerson.add_diagnosis_rdf(rdf, 'arterialHypertension')
    ## maternalHypertension
    rdf += semanticPerson.add_diagnosis_rdf(rdf, 'maternalHypertension')
    ## maternalDiabetes
    rdf += semanticPerson.add_diagnosis_rdf(rdf, 'maternalDiabetes')
    ## diabetesMellitusType1
    rdf += semanticPerson.add_diagnosis_rdf(rdf, 'diabetesMellitusType1')
    ## diabetesMellitusType2
    rdf += semanticPerson.add_diagnosis_rdf(rdf, 'diabetesMellitusType2')
    ## dyslipidemia
    rdf += semanticPerson.add_diagnosis_rdf(rdf, 'dyslipidemia')
    
    # treatments
    ## statines
    rdf += semanticPerson.add_drugPrescription_rdf(rdf, 'treatmentStatines')
    ## antiplatelet
    rdf += semanticPerson.add_drugPrescription_rdf(rdf, 'treatmentAntiplatelet')
    ## anticoagulants
    rdf += semanticPerson.add_drugPrescription_rdf(rdf, 'treatmentAnticoagulant')

    full_rdf = prefix + "\n" + rdf

    if verbose == False:
        print("======= RDF DATA =======")
        print(full_rdf)
        print("========================")

    kg.parse(data=full_rdf, format="turtle")


## Serialize data
testing = False
if testing == True:
    print("Testing mode, generating a small RDF file with a couple of individuals.")
    #
    kg = Dataset()
    synicadf[0:10].apply(generate_semanticBiollection_rdf, axis=1, kg=kg)
    print(f"Generated {len(kg)} RDF triples")
    kg.serialize(destination="deliverable/synican3_testing.ttl", format="turtle")
else:
## Serialize data
    nbindividualsatonce = 10
    totalindividuals = len(synicadf)
    for i in range(0, totalindividuals, nbindividualsatonce):
        print("Fullrun mode, generating several files with all individuals.")
        counter = i 
        print(f"Processing {counter} : {i} to {i+nbindividualsatonce} lines (of total individuals {totalindividuals})")
        #
        kg = Dataset()
        synicadf[i:i+nbindividualsatonce].apply(generate_semanticBiollection_rdf, axis=1, kg=kg)
        print(f"Generated {len(kg)} RDF triples")
        kg.serialize(destination="deliverable/chunks/synican3_"+str(counter)+".ttl", format="turtle")
# Out:
# Fullrun mode, generating several files with all individuals.
# Processing 0 : 0 to 10 lines (of total individuals 3000)
# Generated 643 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 10 : 10 to 20 lines (of total individuals 3000)
# Generated 647 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 20 : 20 to 30 lines (of total individuals 3000)
# Generated 623 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 30 : 30 to 40 lines (of total individuals 3000)
# Generated 641 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 40 : 40 to 50 lines (of total individuals 3000)
# Generated 635 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 50 : 50 to 60 lines (of total individuals 3000)
# Generated 643 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 60 : 60 to 70 lines (of total individuals 3000)
# Generated 635 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 70 : 70 to 80 lines (of total individuals 3000)
# Generated 635 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 80 : 80 to 90 lines (of total individuals 3000)
# Generated 651 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 90 : 90 to 100 lines (of total individuals 3000)
# Generated 639 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 100 : 100 to 110 lines (of total individuals 3000)
# Generated 643 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 110 : 110 to 120 lines (of total individuals 3000)
# Generated 633 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 120 : 120 to 130 lines (of total individuals 3000)
# Generated 627 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 130 : 130 to 140 lines (of total individuals 3000)
# Generated 623 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 140 : 140 to 150 lines (of total individuals 3000)
# Generated 631 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 150 : 150 to 160 lines (of total individuals 3000)
# Generated 637 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 160 : 160 to 170 lines (of total individuals 3000)
# Generated 633 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 170 : 170 to 180 lines (of total individuals 3000)
# Generated 639 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 180 : 180 to 190 lines (of total individuals 3000)
# Generated 647 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 190 : 190 to 200 lines (of total individuals 3000)
# Generated 643 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 200 : 200 to 210 lines (of total individuals 3000)
# Generated 653 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 210 : 210 to 220 lines (of total individuals 3000)
# Generated 641 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 220 : 220 to 230 lines (of total individuals 3000)
# Generated 665 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 230 : 230 to 240 lines (of total individuals 3000)
# Generated 633 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 240 : 240 to 250 lines (of total individuals 3000)
# Generated 629 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 250 : 250 to 260 lines (of total individuals 3000)
# Generated 639 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 260 : 260 to 270 lines (of total individuals 3000)
# Generated 667 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 270 : 270 to 280 lines (of total individuals 3000)
# Generated 659 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 280 : 280 to 290 lines (of total individuals 3000)
# Generated 627 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 290 : 290 to 300 lines (of total individuals 3000)
# Generated 641 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 300 : 300 to 310 lines (of total individuals 3000)
# Generated 641 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 310 : 310 to 320 lines (of total individuals 3000)
# Generated 653 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 320 : 320 to 330 lines (of total individuals 3000)
# Generated 641 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 330 : 330 to 340 lines (of total individuals 3000)
# Generated 627 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 340 : 340 to 350 lines (of total individuals 3000)
# Generated 667 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 350 : 350 to 360 lines (of total individuals 3000)
# Generated 643 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 360 : 360 to 370 lines (of total individuals 3000)
# Generated 651 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 370 : 370 to 380 lines (of total individuals 3000)
# Generated 645 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 380 : 380 to 390 lines (of total individuals 3000)
# Generated 649 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 390 : 390 to 400 lines (of total individuals 3000)
# Generated 629 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 400 : 400 to 410 lines (of total individuals 3000)
# Generated 631 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 410 : 410 to 420 lines (of total individuals 3000)
# Generated 655 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 420 : 420 to 430 lines (of total individuals 3000)
# Generated 639 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 430 : 430 to 440 lines (of total individuals 3000)
# Generated 643 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 440 : 440 to 450 lines (of total individuals 3000)
# Generated 649 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 450 : 450 to 460 lines (of total individuals 3000)
# Generated 647 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 460 : 460 to 470 lines (of total individuals 3000)
# Generated 651 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 470 : 470 to 480 lines (of total individuals 3000)
# Generated 639 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 480 : 480 to 490 lines (of total individuals 3000)
# Generated 651 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 490 : 490 to 500 lines (of total individuals 3000)
# Generated 647 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 500 : 500 to 510 lines (of total individuals 3000)
# Generated 655 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 510 : 510 to 520 lines (of total individuals 3000)
# Generated 651 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 520 : 520 to 530 lines (of total individuals 3000)
# Generated 657 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 530 : 530 to 540 lines (of total individuals 3000)
# Generated 635 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 540 : 540 to 550 lines (of total individuals 3000)
# Generated 635 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 550 : 550 to 560 lines (of total individuals 3000)
# Generated 619 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 560 : 560 to 570 lines (of total individuals 3000)
# Generated 659 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 570 : 570 to 580 lines (of total individuals 3000)
# Generated 641 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 580 : 580 to 590 lines (of total individuals 3000)
# Generated 629 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 590 : 590 to 600 lines (of total individuals 3000)
# Generated 637 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 600 : 600 to 610 lines (of total individuals 3000)
# Generated 643 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 610 : 610 to 620 lines (of total individuals 3000)
# Generated 643 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 620 : 620 to 630 lines (of total individuals 3000)
# Generated 637 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 630 : 630 to 640 lines (of total individuals 3000)
# Generated 627 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 640 : 640 to 650 lines (of total individuals 3000)
# Generated 629 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 650 : 650 to 660 lines (of total individuals 3000)
# Generated 639 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 660 : 660 to 670 lines (of total individuals 3000)
# Generated 651 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 670 : 670 to 680 lines (of total individuals 3000)
# Generated 639 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 680 : 680 to 690 lines (of total individuals 3000)
# Generated 653 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 690 : 690 to 700 lines (of total individuals 3000)
# Generated 617 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 700 : 700 to 710 lines (of total individuals 3000)
# Generated 633 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 710 : 710 to 720 lines (of total individuals 3000)
# Generated 653 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 720 : 720 to 730 lines (of total individuals 3000)
# Generated 657 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 730 : 730 to 740 lines (of total individuals 3000)
# Generated 637 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 740 : 740 to 750 lines (of total individuals 3000)
# Generated 625 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 750 : 750 to 760 lines (of total individuals 3000)
# Generated 639 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 760 : 760 to 770 lines (of total individuals 3000)
# Generated 623 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 770 : 770 to 780 lines (of total individuals 3000)
# Generated 645 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 780 : 780 to 790 lines (of total individuals 3000)
# Generated 633 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 790 : 790 to 800 lines (of total individuals 3000)
# Generated 647 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 800 : 800 to 810 lines (of total individuals 3000)
# Generated 657 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 810 : 810 to 820 lines (of total individuals 3000)
# Generated 627 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 820 : 820 to 830 lines (of total individuals 3000)
# Generated 633 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 830 : 830 to 840 lines (of total individuals 3000)
# Generated 637 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 840 : 840 to 850 lines (of total individuals 3000)
# Generated 641 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 850 : 850 to 860 lines (of total individuals 3000)
# Generated 649 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 860 : 860 to 870 lines (of total individuals 3000)
# Generated 637 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 870 : 870 to 880 lines (of total individuals 3000)
# Generated 643 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 880 : 880 to 890 lines (of total individuals 3000)
# Generated 635 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 890 : 890 to 900 lines (of total individuals 3000)
# Generated 649 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 900 : 900 to 910 lines (of total individuals 3000)
# Generated 623 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 910 : 910 to 920 lines (of total individuals 3000)
# Generated 649 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 920 : 920 to 930 lines (of total individuals 3000)
# Generated 649 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 930 : 930 to 940 lines (of total individuals 3000)
# Generated 631 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 940 : 940 to 950 lines (of total individuals 3000)
# Generated 659 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 950 : 950 to 960 lines (of total individuals 3000)
# Generated 643 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 960 : 960 to 970 lines (of total individuals 3000)
# Generated 643 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 970 : 970 to 980 lines (of total individuals 3000)
# Generated 637 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 980 : 980 to 990 lines (of total individuals 3000)
# Generated 629 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 990 : 990 to 1000 lines (of total individuals 3000)
# Generated 667 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1000 : 1000 to 1010 lines (of total individuals 3000)
# Generated 643 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1010 : 1010 to 1020 lines (of total individuals 3000)
# Generated 631 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1020 : 1020 to 1030 lines (of total individuals 3000)
# Generated 639 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1030 : 1030 to 1040 lines (of total individuals 3000)
# Generated 631 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1040 : 1040 to 1050 lines (of total individuals 3000)
# Generated 655 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1050 : 1050 to 1060 lines (of total individuals 3000)
# Generated 641 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1060 : 1060 to 1070 lines (of total individuals 3000)
# Generated 633 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1070 : 1070 to 1080 lines (of total individuals 3000)
# Generated 641 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1080 : 1080 to 1090 lines (of total individuals 3000)
# Generated 657 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1090 : 1090 to 1100 lines (of total individuals 3000)
# Generated 629 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1100 : 1100 to 1110 lines (of total individuals 3000)
# Generated 665 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1110 : 1110 to 1120 lines (of total individuals 3000)
# Generated 643 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1120 : 1120 to 1130 lines (of total individuals 3000)
# Generated 629 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1130 : 1130 to 1140 lines (of total individuals 3000)
# Generated 657 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1140 : 1140 to 1150 lines (of total individuals 3000)
# Generated 647 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1150 : 1150 to 1160 lines (of total individuals 3000)
# Generated 659 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1160 : 1160 to 1170 lines (of total individuals 3000)
# Generated 641 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1170 : 1170 to 1180 lines (of total individuals 3000)
# Generated 633 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1180 : 1180 to 1190 lines (of total individuals 3000)
# Generated 635 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1190 : 1190 to 1200 lines (of total individuals 3000)
# Generated 633 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1200 : 1200 to 1210 lines (of total individuals 3000)
# Generated 631 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1210 : 1210 to 1220 lines (of total individuals 3000)
# Generated 631 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1220 : 1220 to 1230 lines (of total individuals 3000)
# Generated 641 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1230 : 1230 to 1240 lines (of total individuals 3000)
# Generated 641 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1240 : 1240 to 1250 lines (of total individuals 3000)
# Generated 641 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1250 : 1250 to 1260 lines (of total individuals 3000)
# Generated 623 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1260 : 1260 to 1270 lines (of total individuals 3000)
# Generated 643 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1270 : 1270 to 1280 lines (of total individuals 3000)
# Generated 633 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1280 : 1280 to 1290 lines (of total individuals 3000)
# Generated 649 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1290 : 1290 to 1300 lines (of total individuals 3000)
# Generated 639 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1300 : 1300 to 1310 lines (of total individuals 3000)
# Generated 621 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1310 : 1310 to 1320 lines (of total individuals 3000)
# Generated 627 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1320 : 1320 to 1330 lines (of total individuals 3000)
# Generated 663 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1330 : 1330 to 1340 lines (of total individuals 3000)
# Generated 629 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1340 : 1340 to 1350 lines (of total individuals 3000)
# Generated 635 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1350 : 1350 to 1360 lines (of total individuals 3000)
# Generated 647 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1360 : 1360 to 1370 lines (of total individuals 3000)
# Generated 643 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1370 : 1370 to 1380 lines (of total individuals 3000)
# Generated 631 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1380 : 1380 to 1390 lines (of total individuals 3000)
# Generated 661 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1390 : 1390 to 1400 lines (of total individuals 3000)
# Generated 667 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1400 : 1400 to 1410 lines (of total individuals 3000)
# Generated 651 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1410 : 1410 to 1420 lines (of total individuals 3000)
# Generated 625 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1420 : 1420 to 1430 lines (of total individuals 3000)
# Generated 649 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1430 : 1430 to 1440 lines (of total individuals 3000)
# Generated 651 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1440 : 1440 to 1450 lines (of total individuals 3000)
# Generated 637 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1450 : 1450 to 1460 lines (of total individuals 3000)
# Generated 647 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1460 : 1460 to 1470 lines (of total individuals 3000)
# Generated 645 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1470 : 1470 to 1480 lines (of total individuals 3000)
# Generated 623 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1480 : 1480 to 1490 lines (of total individuals 3000)
# Generated 649 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1490 : 1490 to 1500 lines (of total individuals 3000)
# Generated 627 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1500 : 1500 to 1510 lines (of total individuals 3000)
# Generated 669 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1510 : 1510 to 1520 lines (of total individuals 3000)
# Generated 641 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1520 : 1520 to 1530 lines (of total individuals 3000)
# Generated 641 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1530 : 1530 to 1540 lines (of total individuals 3000)
# Generated 639 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1540 : 1540 to 1550 lines (of total individuals 3000)
# Generated 643 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1550 : 1550 to 1560 lines (of total individuals 3000)
# Generated 643 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1560 : 1560 to 1570 lines (of total individuals 3000)
# Generated 633 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1570 : 1570 to 1580 lines (of total individuals 3000)
# Generated 631 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1580 : 1580 to 1590 lines (of total individuals 3000)
# Generated 625 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1590 : 1590 to 1600 lines (of total individuals 3000)
# Generated 647 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1600 : 1600 to 1610 lines (of total individuals 3000)
# Generated 627 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1610 : 1610 to 1620 lines (of total individuals 3000)
# Generated 651 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1620 : 1620 to 1630 lines (of total individuals 3000)
# Generated 645 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1630 : 1630 to 1640 lines (of total individuals 3000)
# Generated 639 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1640 : 1640 to 1650 lines (of total individuals 3000)
# Generated 655 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1650 : 1650 to 1660 lines (of total individuals 3000)
# Generated 631 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1660 : 1660 to 1670 lines (of total individuals 3000)
# Generated 643 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1670 : 1670 to 1680 lines (of total individuals 3000)
# Generated 637 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1680 : 1680 to 1690 lines (of total individuals 3000)
# Generated 639 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1690 : 1690 to 1700 lines (of total individuals 3000)
# Generated 615 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1700 : 1700 to 1710 lines (of total individuals 3000)
# Generated 655 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1710 : 1710 to 1720 lines (of total individuals 3000)
# Generated 665 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1720 : 1720 to 1730 lines (of total individuals 3000)
# Generated 635 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1730 : 1730 to 1740 lines (of total individuals 3000)
# Generated 651 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1740 : 1740 to 1750 lines (of total individuals 3000)
# Generated 649 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1750 : 1750 to 1760 lines (of total individuals 3000)
# Generated 653 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1760 : 1760 to 1770 lines (of total individuals 3000)
# Generated 633 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1770 : 1770 to 1780 lines (of total individuals 3000)
# Generated 645 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1780 : 1780 to 1790 lines (of total individuals 3000)
# Generated 647 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1790 : 1790 to 1800 lines (of total individuals 3000)
# Generated 661 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1800 : 1800 to 1810 lines (of total individuals 3000)
# Generated 627 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1810 : 1810 to 1820 lines (of total individuals 3000)
# Generated 629 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1820 : 1820 to 1830 lines (of total individuals 3000)
# Generated 619 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1830 : 1830 to 1840 lines (of total individuals 3000)
# Generated 637 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1840 : 1840 to 1850 lines (of total individuals 3000)
# Generated 629 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1850 : 1850 to 1860 lines (of total individuals 3000)
# Generated 639 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1860 : 1860 to 1870 lines (of total individuals 3000)
# Generated 635 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1870 : 1870 to 1880 lines (of total individuals 3000)
# Generated 663 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1880 : 1880 to 1890 lines (of total individuals 3000)
# Generated 643 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1890 : 1890 to 1900 lines (of total individuals 3000)
# Generated 633 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1900 : 1900 to 1910 lines (of total individuals 3000)
# Generated 625 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1910 : 1910 to 1920 lines (of total individuals 3000)
# Generated 631 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1920 : 1920 to 1930 lines (of total individuals 3000)
# Generated 655 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1930 : 1930 to 1940 lines (of total individuals 3000)
# Generated 629 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1940 : 1940 to 1950 lines (of total individuals 3000)
# Generated 631 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1950 : 1950 to 1960 lines (of total individuals 3000)
# Generated 653 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1960 : 1960 to 1970 lines (of total individuals 3000)
# Generated 647 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1970 : 1970 to 1980 lines (of total individuals 3000)
# Generated 645 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1980 : 1980 to 1990 lines (of total individuals 3000)
# Generated 629 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 1990 : 1990 to 2000 lines (of total individuals 3000)
# Generated 637 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2000 : 2000 to 2010 lines (of total individuals 3000)
# Generated 663 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2010 : 2010 to 2020 lines (of total individuals 3000)
# Generated 643 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2020 : 2020 to 2030 lines (of total individuals 3000)
# Generated 633 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2030 : 2030 to 2040 lines (of total individuals 3000)
# Generated 637 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2040 : 2040 to 2050 lines (of total individuals 3000)
# Generated 637 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2050 : 2050 to 2060 lines (of total individuals 3000)
# Generated 625 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2060 : 2060 to 2070 lines (of total individuals 3000)
# Generated 645 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2070 : 2070 to 2080 lines (of total individuals 3000)
# Generated 627 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2080 : 2080 to 2090 lines (of total individuals 3000)
# Generated 655 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2090 : 2090 to 2100 lines (of total individuals 3000)
# Generated 653 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2100 : 2100 to 2110 lines (of total individuals 3000)
# Generated 663 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2110 : 2110 to 2120 lines (of total individuals 3000)
# Generated 655 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2120 : 2120 to 2130 lines (of total individuals 3000)
# Generated 645 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2130 : 2130 to 2140 lines (of total individuals 3000)
# Generated 653 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2140 : 2140 to 2150 lines (of total individuals 3000)
# Generated 645 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2150 : 2150 to 2160 lines (of total individuals 3000)
# Generated 645 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2160 : 2160 to 2170 lines (of total individuals 3000)
# Generated 637 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2170 : 2170 to 2180 lines (of total individuals 3000)
# Generated 641 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2180 : 2180 to 2190 lines (of total individuals 3000)
# Generated 639 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2190 : 2190 to 2200 lines (of total individuals 3000)
# Generated 625 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2200 : 2200 to 2210 lines (of total individuals 3000)
# Generated 637 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2210 : 2210 to 2220 lines (of total individuals 3000)
# Generated 643 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2220 : 2220 to 2230 lines (of total individuals 3000)
# Generated 645 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2230 : 2230 to 2240 lines (of total individuals 3000)
# Generated 623 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2240 : 2240 to 2250 lines (of total individuals 3000)
# Generated 655 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2250 : 2250 to 2260 lines (of total individuals 3000)
# Generated 641 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2260 : 2260 to 2270 lines (of total individuals 3000)
# Generated 613 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2270 : 2270 to 2280 lines (of total individuals 3000)
# Generated 629 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2280 : 2280 to 2290 lines (of total individuals 3000)
# Generated 629 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2290 : 2290 to 2300 lines (of total individuals 3000)
# Generated 661 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2300 : 2300 to 2310 lines (of total individuals 3000)
# Generated 647 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2310 : 2310 to 2320 lines (of total individuals 3000)
# Generated 651 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2320 : 2320 to 2330 lines (of total individuals 3000)
# Generated 635 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2330 : 2330 to 2340 lines (of total individuals 3000)
# Generated 647 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2340 : 2340 to 2350 lines (of total individuals 3000)
# Generated 645 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2350 : 2350 to 2360 lines (of total individuals 3000)
# Generated 665 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2360 : 2360 to 2370 lines (of total individuals 3000)
# Generated 651 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2370 : 2370 to 2380 lines (of total individuals 3000)
# Generated 649 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2380 : 2380 to 2390 lines (of total individuals 3000)
# Generated 657 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2390 : 2390 to 2400 lines (of total individuals 3000)
# Generated 643 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2400 : 2400 to 2410 lines (of total individuals 3000)
# Generated 635 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2410 : 2410 to 2420 lines (of total individuals 3000)
# Generated 631 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2420 : 2420 to 2430 lines (of total individuals 3000)
# Generated 631 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2430 : 2430 to 2440 lines (of total individuals 3000)
# Generated 623 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2440 : 2440 to 2450 lines (of total individuals 3000)
# Generated 645 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2450 : 2450 to 2460 lines (of total individuals 3000)
# Generated 631 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2460 : 2460 to 2470 lines (of total individuals 3000)
# Generated 639 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2470 : 2470 to 2480 lines (of total individuals 3000)
# Generated 633 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2480 : 2480 to 2490 lines (of total individuals 3000)
# Generated 635 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2490 : 2490 to 2500 lines (of total individuals 3000)
# Generated 647 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2500 : 2500 to 2510 lines (of total individuals 3000)
# Generated 653 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2510 : 2510 to 2520 lines (of total individuals 3000)
# Generated 623 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2520 : 2520 to 2530 lines (of total individuals 3000)
# Generated 615 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2530 : 2530 to 2540 lines (of total individuals 3000)
# Generated 653 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2540 : 2540 to 2550 lines (of total individuals 3000)
# Generated 643 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2550 : 2550 to 2560 lines (of total individuals 3000)
# Generated 643 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2560 : 2560 to 2570 lines (of total individuals 3000)
# Generated 621 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2570 : 2570 to 2580 lines (of total individuals 3000)
# Generated 641 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2580 : 2580 to 2590 lines (of total individuals 3000)
# Generated 657 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2590 : 2590 to 2600 lines (of total individuals 3000)
# Generated 619 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2600 : 2600 to 2610 lines (of total individuals 3000)
# Generated 619 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2610 : 2610 to 2620 lines (of total individuals 3000)
# Generated 645 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2620 : 2620 to 2630 lines (of total individuals 3000)
# Generated 653 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2630 : 2630 to 2640 lines (of total individuals 3000)
# Generated 637 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2640 : 2640 to 2650 lines (of total individuals 3000)
# Generated 647 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2650 : 2650 to 2660 lines (of total individuals 3000)
# Generated 651 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2660 : 2660 to 2670 lines (of total individuals 3000)
# Generated 651 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2670 : 2670 to 2680 lines (of total individuals 3000)
# Generated 639 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2680 : 2680 to 2690 lines (of total individuals 3000)
# Generated 637 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2690 : 2690 to 2700 lines (of total individuals 3000)
# Generated 633 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2700 : 2700 to 2710 lines (of total individuals 3000)
# Generated 639 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2710 : 2710 to 2720 lines (of total individuals 3000)
# Generated 669 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2720 : 2720 to 2730 lines (of total individuals 3000)
# Generated 643 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2730 : 2730 to 2740 lines (of total individuals 3000)
# Generated 649 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2740 : 2740 to 2750 lines (of total individuals 3000)
# Generated 673 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2750 : 2750 to 2760 lines (of total individuals 3000)
# Generated 635 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2760 : 2760 to 2770 lines (of total individuals 3000)
# Generated 645 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2770 : 2770 to 2780 lines (of total individuals 3000)
# Generated 655 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2780 : 2780 to 2790 lines (of total individuals 3000)
# Generated 635 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2790 : 2790 to 2800 lines (of total individuals 3000)
# Generated 641 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2800 : 2800 to 2810 lines (of total individuals 3000)
# Generated 649 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2810 : 2810 to 2820 lines (of total individuals 3000)
# Generated 669 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2820 : 2820 to 2830 lines (of total individuals 3000)
# Generated 639 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2830 : 2830 to 2840 lines (of total individuals 3000)
# Generated 669 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2840 : 2840 to 2850 lines (of total individuals 3000)
# Generated 649 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2850 : 2850 to 2860 lines (of total individuals 3000)
# Generated 641 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2860 : 2860 to 2870 lines (of total individuals 3000)
# Generated 653 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2870 : 2870 to 2880 lines (of total individuals 3000)
# Generated 621 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2880 : 2880 to 2890 lines (of total individuals 3000)
# Generated 645 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2890 : 2890 to 2900 lines (of total individuals 3000)
# Generated 613 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2900 : 2900 to 2910 lines (of total individuals 3000)
# Generated 631 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2910 : 2910 to 2920 lines (of total individuals 3000)
# Generated 631 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2920 : 2920 to 2930 lines (of total individuals 3000)
# Generated 627 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2930 : 2930 to 2940 lines (of total individuals 3000)
# Generated 631 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2940 : 2940 to 2950 lines (of total individuals 3000)
# Generated 641 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2950 : 2950 to 2960 lines (of total individuals 3000)
# Generated 655 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2960 : 2960 to 2970 lines (of total individuals 3000)
# Generated 625 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2970 : 2970 to 2980 lines (of total individuals 3000)
# Generated 651 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2980 : 2980 to 2990 lines (of total individuals 3000)
# Generated 645 RDF triples
# Fullrun mode, generating several files with all individuals.
# Processing 2990 : 2990 to 3000 lines (of total individuals 3000)
# Generated 633 RDF triples
